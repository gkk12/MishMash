# %%
import pandas as pd
import numpy as np
import nltk.data
import codecs
import os

# %%
df = pd.read_csv('sampledata.csv')
df1= pd.read_csv('output.csv',header=None)
df
# Out:
#     Item Code                                        Description  \
# 0        2240                  ADIDAS DYNAMIC PULSE SH GEL 250ML
# 1        4890             Adidas Dynamic Pulse Shower Gel 250 Ml
# 2       80330     ADIDAS EXTREME POWER AFTER SHAVE LOTION 100 ML
# 3        3527              Adidas Extreme Power Deodorant 150 Ml
# 4       90775            Jovees Gold 24 Carat Massage Gel 100 Gm
# 5        4034             Jovees Gold 24 Carat Massage Gel 50 Gm
# 6      234311         Jovees Gold 24 Carat Mini Facial Kit 75 Gm
# 7        5159       KARACHI BAKERY TRIPLE DELIGHT BISCUITS 600GM
# 8      127484  KARACHI BAKERY TRIPLE DELIGHT FRUIT BISCUIT WI...
# 9         215  KESH KING-ALOE VERA HERBAL SHAMPOO 100ML PACK ...
# 10      16547                      Dove Honey Shampoo 400Ml Pump
#
#         Brand Name Grammage  Sample MRP discount  Selling Price       Barcode
# 0           Adidas   250 ml          87      10%           78.3  4.808230e+11
# ...

# %%
df1
# Out:
#                                                    0                   1  \
# 0                                        Search Term            Boosting
# 1                          Shampoos less than 300 rs  Brand Name == Dove
# 2                          Shampoos less than 300 rs                None
# 3                                             Adidas                None
# 4                                           Biscuits                 NaN
# 5                                 Chocolate Biscuits                 NaN
# 6                                         Facial Kit                 NaN
# 7                      Gold Massage less than 150 rs                 NaN
# 8           Gold Massage with more than 25% discount                 NaN
# 9  Gold Massage with more than 25% discount and l...                 NaN
#
#          2
# 0  Results
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN

# %%
df['Description'].str.lower()
# Out:
# 0                     adidas dynamic pulse sh gel 250ml
# 1                adidas dynamic pulse shower gel 250 ml
# 2        adidas extreme power after shave lotion 100 ml
# 3                 adidas extreme power deodorant 150 ml
# 4               jovees gold 24 carat massage gel 100 gm
# 5                jovees gold 24 carat massage gel 50 gm
# 6            jovees gold 24 carat mini facial kit 75 gm
# 7          karachi bakery triple delight biscuits 600gm
# 8     karachi bakery triple delight fruit biscuit wi...
# 9     kesh king-aloe vera herbal shampoo 100ml pack ...
# 10                        dove honey shampoo 400ml pump
# Name: Description, dtype: object

# %%
np.savetxt(r'C:\Users\Mahe\Desktop\Interview\Hackathon\MishMash\tokens.txt', df['Description'], fmt='%s')

# %%
a_list = nltk.tokenize.sent_tokenize('C:\\Users\\Mahe\\Desktop\\Interview\\Hackathon\\MishMash\tokens.txt')
# Out:
#   File "<ipython-input-25-49b77b4d94a2>", line 1
#     a_list = nltk.tokenize.sent_tokenize('C:\Users\Mahe\Desktop\Interview\Hackathon\MishMash\tokens.txt')
#                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
